# %%
# useful library
import pandas as pd

# %%
#reading data from a file
data=pd.read_csv("ZomatoRestaurantsIndia.csv")

# %%
data.head()
# Out:
#     res_id                            name  establishment  \
# 0  3400299                     Bikanervala    Quick Bites
# 1  3400005  Mama Chicken Mama Franky House    Quick Bites
# 2  3401013                   Bhagat Halwai    Quick Bites
# 3  3400290                   Bhagat Halwai    Quick Bites
# 4  3401744     The Salt Cafe Kitchen & Bar  Casual Dining
#
#                                                  url  \
# 0  https://www.zomato.com/agra/bikanervala-khanda...
# 1  https://www.zomato.com/agra/mama-chicken-mama-...
# 2  https://www.zomato.com/agra/bhagat-halwai-2-sh...
# 3  https://www.zomato.com/agra/bhagat-halwai-civi...
# 4  https://www.zomato.com/agra/the-salt-cafe-kitc...
#
#                                              address  city  city_id  \
# 0  Kalyani Point, Near Tulsi Cinema, Bypass Road,...  Agra       34
# 1        Main Market, Sadar Bazaar, Agra Cantt, Agra  Agra       34
# 2  62/1, Near Easy Day, West Shivaji Nagar, Goalp...  Agra       34
# ...

# %%
# getting information and analysing to extract
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211944 entries, 0 to 211943
# Data columns (total 26 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   res_id                211944 non-null  int64
#  1   name                  211944 non-null  object
#  2   establishment         207117 non-null  object
#  3   url                   211944 non-null  object
#  4   address               211810 non-null  object
#  5   city                  211944 non-null  object
#  6   city_id               211944 non-null  int64
#  7   locality              211944 non-null  object
#  8   latitude              211944 non-null  float64
#  9   longitude             211944 non-null  float64
#  10  zipcode               48757 non-null   object
#  11  country_id            211944 non-null  int64
#  12  locality_verbose      211944 non-null  object
#  13  cuisines              210553 non-null  object
# ...

# %%
new_data=data[data['city']=='Dehradun']

# %%
new_data[['price_range']]
# Out:
#        price_range
# 51307            3
# 51308            1
# 51309            2
# 51310            2
# 51311            2
# ...            ...
# 53879            4
# 53880            1
# 53881            3
# 53882            4
# 53883            4
#
# [2577 rows x 1 columns]

# %%
new_data.head()
# Out:
#          res_id             name  establishment  \
# 51307   3500024      Doon Darbar  Casual Dining
# 51308   3500424   Gaylord Xpress    Quick Bites
# 51309   3500218     Uss Da Dhaba          Dhaba
# 51310  18754629    Dominos Pizza    Quick Bites
# 51311   3502144  Mannu Fast Food    Quick Bites
#
#                                                      url  \
# 51307  https://www.zomato.com/dehradun/doon-darbar-pa...
# 51308  https://www.zomato.com/dehradun/gaylord-xpress...
# 51309  https://www.zomato.com/dehradun/uss-da-dhaba-1...
# 51310  https://www.zomato.com/dehradun/dominos-pizza-...
# 51311  https://www.zomato.com/dehradun/mannu-fast-foo...
#
#                                                  address      city  city_id  \
# 51307  35, Gandhi Road, Tehsil Chowk, Dhamawala Mohal...  Dehradun       35
# 51308      9, Near Samsung Shop, Paltan Bazaar, Dehradun  Dehradun       35
# 51309  Near Hotel Saurab, 3 Court Road, Race Course, ...  Dehradun       35
# ...

# %%
type(new_data.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
ind=[]
for i in new_data.columns:
    ind.append(i)

# %%
ind
# Out:
# ['res_id',
#  'name',
#  'establishment',
#  'url',
#  'address',
#  'city',
#  'city_id',
#  'locality',
#  'latitude',
#  'longitude',
#  'zipcode',
#  'country_id',
#  'locality_verbose',
#  'cuisines',
#  'timings',
#  'average_cost_for_two',
#  'price_range',
#  'currency',
#  'highlights',
#  'aggregate_rating',
#  'rating_text',
#  'votes',
#  'photo_count',
#  'opentable_support',
#  'delivery',
#  'takeaway']

# %%
new_data[ ['average_cost_for_two','price_range']]
# Out:
#        average_cost_for_two  price_range
# 51307                   500            3
# 51308                   200            1
# 51309                   350            2
# 51310                   400            2
# 51311                   250            2
# ...                     ...          ...
# 53879                  1200            4
# 53880                   100            1
# 53881                   600            3
# 53882                  1000            4
# 53883                  1200            4
#
# [2577 rows x 2 columns]

# %%
new_data.describe()
# Out:
#              res_id  city_id     latitude    longitude  country_id  \
# count  2.577000e+03   2577.0  2577.000000  2577.000000      2577.0
# mean   7.510354e+06     35.0    30.087487    77.405341         1.0
# std    6.706544e+06      0.0     2.727840     7.017603         0.0
# min    3.500005e+06     35.0     0.000000     0.000000         1.0
# 25%    3.500378e+06     35.0    30.321939    78.020990         1.0
# 50%    3.500969e+06     35.0    30.332430    78.046760         1.0
# 75%    1.828516e+07     35.0    30.346857    78.062400         1.0
# max    1.915761e+07     35.0    30.411651    78.160537         1.0
#
#        average_cost_for_two  price_range  aggregate_rating        votes  \
# count           2577.000000  2577.000000       2577.000000  2577.000000
# mean             527.461389     2.460225          3.554792   179.816841
# std              340.478811     0.953128          1.115386   205.992115
# min                0.000000     1.000000          0.000000     0.000000
# ...

# %%
new_data.isnull().sum()
# Out:
# res_id                     0
# name                       0
# establishment             23
# url                        0
# address                    0
# city                       0
# city_id                    0
# locality                   0
# latitude                   0
# longitude                  0
# zipcode                 2023
# country_id                 0
# locality_verbose           0
# cuisines                  13
# timings                    4
# average_cost_for_two       0
# price_range                0
# currency                   0
# highlights                 5
# aggregate_rating           0
# rating_text                0
# votes                      0
# photo_count                0
# opentable_support          0
# delivery                   0
# takeaway                   0
# dtype: int64

# %%
new_data=new_data.reset_index()

# %%
drop_col=['price_range','currency','index','zipcode']
new_data.drop(columns=drop_col,axis=1,inplace=True)

# %%
new_data['establishment'].unique()
# Out:
# array(['Casual Dining', 'Quick Bites', 'Dhaba', 'Café', 'Bakery',
#        'Fine Dining', 'Dessert Parlour', 'Sweet Shop', 'Food Truck',
#        'Microbrewery', 'Lounge', 'Pub', 'Bar', nan, 'Kiosk',
#        'Beverage Shop', 'Food Court', 'Confectionery', 'Butcher Shop',
#        'Bhojanalya', 'Mess', 'Paan Shop'], dtype=object)

# %%
# Working on null values
null_values=pd.isnull(new_data['establishment'])
null_data=new_data[null_values]
lst=list(null_data['res_id'])

# %%
def fill_data(x):
    if pd.isna(x)==True:
        return "Restaurant/Shop"
    else:
        return x

# %%
new_data['establishment']=new_data['establishment'].apply(fill_data)
new_data
# Out:
#         res_id                                name  establishment  \
# 0      3500024                         Doon Darbar  Casual Dining
# 1      3500424                      Gaylord Xpress    Quick Bites
# 2      3500218                        Uss Da Dhaba          Dhaba
# 3     18754629                       Dominos Pizza    Quick Bites
# 4      3502144                     Mannu Fast Food    Quick Bites
# ...        ...                                 ...            ...
# 2572   3500497                           Mirabilia  Casual Dining
# 2573   3500393               The Buffet Snack Shop         Bakery
# 2574  18888295                     The Swings Cafe  Casual Dining
# 2575   3500913                         Edens Grove  Casual Dining
# 2576   3500096  Vatika Restaurant - Hotel Madhuban    Fine Dining
#
#                                                     url  \
# 0     https://www.zomato.com/dehradun/doon-darbar-pa...
# 1     https://www.zomato.com/dehradun/gaylord-xpress...
# ...

# %%
# Working on null values
null_values=pd.isnull(new_data['establishment'])
null_data=new_data[null_values]
# Out:
#         res_id                        name establishment  \
# 155    3500037             Barbeque Planet           NaN
# 224   18697636  Muradabadi Chicken Biryani           NaN
# 240   18699399           Pappu Pakode Wale           NaN
# 259   18840778                Atram Patram           NaN
# 274    3502125              Roll Baby Roll           NaN
# 281   19056873               Punjabi Rasoi           NaN
# 285   18967293              Roll Baby Roll           NaN
# 379   19089404                     Tahinis           NaN
# 429   18696975          Bhaiya Samose Wale           NaN
# 457   18695187               Chicken Point           NaN
# 464   19096732               Thaliwala.com           NaN
# 466    3500050         Banjaara Restaurant           NaN
# 473   19008379            Fast Food Center           NaN
# 490   19058109         Ashirwad Restaurant           NaN
# 495   18699399           Pappu Pakode Wale           NaN
# ...

# %%
new_data['highlights'].value_counts()
# Out:
# No Alcohol Available, Dinner, Cash, Takeaway Available, Debit Card, Lunch, Delivery, Credit Card, Free Parking, Indoor Seating, Air Conditioned                                                                                                                                                                                                                                                                24
# Cash, Dinner, Debit Card, Takeaway Available, Breakfast, Credit Card, Delivery, Desserts and Bakes, Digital Payments Accepted, Wifi, Air Conditioned, Indoor Seating, Free Wifi, Self Service                                                                                                                                                                                                                  21
# ...

# %%
new_data[new_data['highlights'].isnull()==True]
# Out:
#        res_id                        name establishment  \
# 224  18697636  Muradabadi Chicken Biryani           NaN
# 240  18699399           Pappu Pakode Wale           NaN
# 261   3501559      New Diksha Bhojanalaya   Quick Bites
# 429  18696975          Bhaiya Samose Wale           NaN
# 495  18699399           Pappu Pakode Wale           NaN
#
#                                                    url  \
# 224  https://www.zomato.com/dehradun/muradabadi-chi...
# 240  https://www.zomato.com/dehradun/pappu-pakode-w...
# 261  https://www.zomato.com/dehradun/new-diksha-bho...
# 429  https://www.zomato.com/dehradun/bhaiya-samose-...
# 495  https://www.zomato.com/dehradun/pappu-pakode-w...
#
#                                                address      city  city_id  \
# 224  Inamullah Building, Gandhi Road, Paltan Bazaar...  Dehradun       35
# 240                              Near Prem Nagar Chowk  Dehradun       35
# ...

# %%
def high(x):
    if pd.isna(x)==True:
        return "Available, Cash"
    else:
        return x

# %%
new_data['highlights']=new_data['highlights'].apply(high)

# %%
new_data.isnull().sum()
# Out:
# res_id                   0
# name                     0
# establishment            0
# url                      0
# address                  0
# city                     0
# city_id                  0
# locality                 0
# latitude                 0
# longitude                0
# country_id               0
# locality_verbose         0
# cuisines                13
# timings                  4
# average_cost_for_two     0
# highlights               0
# aggregate_rating         0
# rating_text              0
# votes                    0
# photo_count              0
# opentable_support        0
# delivery                 0
# takeaway                 0
# type                     0
# dtype: int64

# %%
def time(x):
    if pd.isna(x)==True:
        return "11 AM to 11 PM"
    else:
        return x
new_data['timings']=new_data['timings'].apply(time)

# %%
def food(x):
    if pd.isna(x)==True:
        return "Fast Food"
    else:
        return x

# %%
new_data['cuisines']=new_data['cuisines'].apply(food)

# %%
new_data
# Out:
#         res_id                                name  establishment  \
# 0      3500024                         Doon Darbar  Casual Dining
# 1      3500424                      Gaylord Xpress    Quick Bites
# 2      3500218                        Uss Da Dhaba          Dhaba
# 3     18754629                       Dominos Pizza    Quick Bites
# 4      3502144                     Mannu Fast Food    Quick Bites
# ...        ...                                 ...            ...
# 2572   3500497                           Mirabilia  Casual Dining
# 2573   3500393               The Buffet Snack Shop         Bakery
# 2574  18888295                     The Swings Cafe  Casual Dining
# 2575   3500913                         Edens Grove  Casual Dining
# 2576   3500096  Vatika Restaurant - Hotel Madhuban    Fine Dining
#
#                                                     url  \
# 0     https://www.zomato.com/dehradun/doon-darbar-pa...
# 1     https://www.zomato.com/dehradun/gaylord-xpress...
# ...

# %%
new_data.drop(columns='type',axis=1)
# Out:
#         res_id                                name  establishment  \
# 0      3500024                         Doon Darbar  Casual Dining
# 1      3500424                      Gaylord Xpress    Quick Bites
# 2      3500218                        Uss Da Dhaba          Dhaba
# 3     18754629                       Dominos Pizza    Quick Bites
# 4      3502144                     Mannu Fast Food    Quick Bites
# ...        ...                                 ...            ...
# 2572   3500497                           Mirabilia  Casual Dining
# 2573   3500393               The Buffet Snack Shop         Bakery
# 2574  18888295                     The Swings Cafe  Casual Dining
# 2575   3500913                         Edens Grove  Casual Dining
# 2576   3500096  Vatika Restaurant - Hotel Madhuban    Fine Dining
#
#                                                     url  \
# 0     https://www.zomato.com/dehradun/doon-darbar-pa...
# 1     https://www.zomato.com/dehradun/gaylord-xpress...
# ...

# %%
#process completed covert it to new csv file
new_data.to_csv('Dehradun_Zomatao_Dataset.csv')
