# %%
import pandas as pd

# %%
data=pd.read_csv("ZomatoRestaurantsIndia.csv")

# %%
data.head()
# Out:
#     res_id                            name  establishment  \
# 0  3400299                     Bikanervala    Quick Bites
# 1  3400005  Mama Chicken Mama Franky House    Quick Bites
# 2  3401013                   Bhagat Halwai    Quick Bites
# 3  3400290                   Bhagat Halwai    Quick Bites
# 4  3401744     The Salt Cafe Kitchen & Bar  Casual Dining
#
#                                                  url  \
# 0  https://www.zomato.com/agra/bikanervala-khanda...
# 1  https://www.zomato.com/agra/mama-chicken-mama-...
# 2  https://www.zomato.com/agra/bhagat-halwai-2-sh...
# 3  https://www.zomato.com/agra/bhagat-halwai-civi...
# 4  https://www.zomato.com/agra/the-salt-cafe-kitc...
#
#                                              address  city  city_id  \
# 0  Kalyani Point, Near Tulsi Cinema, Bypass Road,...  Agra       34
# 1        Main Market, Sadar Bazaar, Agra Cantt, Agra  Agra       34
# 2  62/1, Near Easy Day, West Shivaji Nagar, Goalp...  Agra       34
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211944 entries, 0 to 211943
# Data columns (total 26 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   res_id                211944 non-null  int64
#  1   name                  211944 non-null  object
#  2   establishment         207117 non-null  object
#  3   url                   211944 non-null  object
#  4   address               211810 non-null  object
#  5   city                  211944 non-null  object
#  6   city_id               211944 non-null  int64
#  7   locality              211944 non-null  object
#  8   latitude              211944 non-null  float64
#  9   longitude             211944 non-null  float64
#  10  zipcode               48757 non-null   object
#  11  country_id            211944 non-null  int64
#  12  locality_verbose      211944 non-null  object
#  13  cuisines              210553 non-null  object
# ...

# %%
new_data=data[data['city']=='Dehradun']

# %%
deh_names=data['name']

# %%
cnt=0
for i in deh_names:
    cnt=cnt+1
cnt
# Out:
# 211944

# %%
new_data[['price_range']]
# Out:
#        price_range
# 51307            3
# 51308            1
# 51309            2
# 51310            2
# 51311            2
# ...            ...
# 53879            4
# 53880            1
# 53881            3
# 53882            4
# 53883            4
#
# [2577 rows x 1 columns]

# %%
new_data.index
# Out:
# Int64Index([51307, 51308, 51309, 51310, 51311, 51312, 51313, 51314, 51315,
#             51316,
#             ...
#             53874, 53875, 53876, 53877, 53878, 53879, 53880, 53881, 53882,
#             53883],
#            dtype='int64', length=2577)

# %%
new_data.head()
# Out:
#          res_id             name  establishment  \
# 51307   3500024      Doon Darbar  Casual Dining
# 51308   3500424   Gaylord Xpress    Quick Bites
# 51309   3500218     Uss Da Dhaba          Dhaba
# 51310  18754629    Dominos Pizza    Quick Bites
# 51311   3502144  Mannu Fast Food    Quick Bites
#
#                                                      url  \
# 51307  https://www.zomato.com/dehradun/doon-darbar-pa...
# 51308  https://www.zomato.com/dehradun/gaylord-xpress...
# 51309  https://www.zomato.com/dehradun/uss-da-dhaba-1...
# 51310  https://www.zomato.com/dehradun/dominos-pizza-...
# 51311  https://www.zomato.com/dehradun/mannu-fast-foo...
#
#                                                  address      city  city_id  \
# 51307  35, Gandhi Road, Tehsil Chowk, Dhamawala Mohal...  Dehradun       35
# 51308      9, Near Samsung Shop, Paltan Bazaar, Dehradun  Dehradun       35
# 51309  Near Hotel Saurab, 3 Court Road, Race Course, ...  Dehradun       35
# ...

# %%
type(new_data.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
ind=[]
for i in new_data.columns:
    ind.append(i)

# %%
ind
# Out:
# ['res_id',
#  'name',
#  'establishment',
#  'url',
#  'address',
#  'city',
#  'city_id',
#  'locality',
#  'latitude',
#  'longitude',
#  'zipcode',
#  'country_id',
#  'locality_verbose',
#  'cuisines',
#  'timings',
#  'average_cost_for_two',
#  'price_range',
#  'currency',
#  'highlights',
#  'aggregate_rating',
#  'rating_text',
#  'votes',
#  'photo_count',
#  'opentable_support',
#  'delivery',
#  'takeaway']

# %%
new_data[ ['average_cost_for_two','price_range']]
# Out:
#        average_cost_for_two  price_range
# 51307                   500            3
# 51308                   200            1
# 51309                   350            2
# 51310                   400            2
# 51311                   250            2
# ...                     ...          ...
# 53879                  1200            4
# 53880                   100            1
# 53881                   600            3
# 53882                  1000            4
# 53883                  1200            4
#
# [2577 rows x 2 columns]

# %%
new_data.describe()
# Out:
#              res_id  city_id     latitude    longitude  country_id  \
# count  2.577000e+03   2577.0  2577.000000  2577.000000      2577.0
# mean   7.510354e+06     35.0    30.087487    77.405341         1.0
# std    6.706544e+06      0.0     2.727840     7.017603         0.0
# min    3.500005e+06     35.0     0.000000     0.000000         1.0
# 25%    3.500378e+06     35.0    30.321939    78.020990         1.0
# 50%    3.500969e+06     35.0    30.332430    78.046760         1.0
# 75%    1.828516e+07     35.0    30.346857    78.062400         1.0
# max    1.915761e+07     35.0    30.411651    78.160537         1.0
#
#        average_cost_for_two  price_range  aggregate_rating        votes  \
# count           2577.000000  2577.000000       2577.000000  2577.000000
# mean             527.461389     2.460225          3.554792   179.816841
# std              340.478811     0.953128          1.115386   205.992115
# min                0.000000     1.000000          0.000000     0.000000
# ...

# %%
new_data.isnull().sum()
# Out:
# res_id                     0
# name                       0
# establishment             23
# url                        0
# address                    0
# city                       0
# city_id                    0
# locality                   0
# latitude                   0
# longitude                  0
# zipcode                 2023
# country_id                 0
# locality_verbose           0
# cuisines                  13
# timings                    4
# average_cost_for_two       0
# price_range                0
# currency                   0
# highlights                 5
# aggregate_rating           0
# rating_text                0
# votes                      0
# photo_count                0
# opentable_support          0
# delivery                   0
# takeaway                   0
# dtype: int64

# %%
new_data.drop(columns='currency',axis=1,inplace=True)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
new_data.isnull().sum()
# Out:
# res_id                   0
# name                     0
# establishment           23
# url                      0
# address                  0
# city                     0
# city_id                  0
# locality                 0
# latitude                 0
# longitude                0
# country_id               0
# locality_verbose         0
# cuisines                13
# timings                  4
# average_cost_for_two     0
# price_range              0
# highlights               5
# aggregate_rating         0
# rating_text              0
# votes                    0
# photo_count              0
# opentable_support        0
# delivery                 0
# takeaway                 0
# dtype: int64

# %%
new_data[['highlights','locality_verbose']]
# Out:
#                                               highlights  \
# 51307  Dinner, Delivery, Credit Card, Lunch, Cash, Ta...
# 51308  Cash, Lunch, No Alcohol Available, Credit Card...
# 51309  Lunch, Cash, No Alcohol Available, Dinner, Del...
# 51310  No Alcohol Available, Dinner, Cash, Takeaway A...
# 51311  Dinner, Cash, Delivery, Lunch, Takeaway Availa...
# ...                                                  ...
# 53879  Debit Card, Cash, Takeaway Available, Serves A...
# 53880  No Alcohol Available, Cash, Lunch, Takeaway Av...
# 53881  Credit Card, Lunch, No Alcohol Available, Take...
# 53882  Dinner, Cash, No Alcohol Available, Lunch, Del...
# 53883  Credit Card, Dinner, Serves Alcohol, Lunch, Br...
#
#                                      locality_verbose
# 51307                         Paltan Bazaar, Dehradun
# 51308                         Paltan Bazaar, Dehradun
# 51309                           Race Course, Dehradun
# 51310                                Rajpur, Dehradun
# ...

# %%
dehradun_zomato_data=new_data

# %%
new_data.reset_index(inplace=True)

# %%
new_data.drop(columns='index',axis=1)
# Out:
#         res_id                                name  establishment  \
# 0      3500024                         Doon Darbar  Casual Dining
# 1      3500424                      Gaylord Xpress    Quick Bites
# 2      3500218                        Uss Da Dhaba          Dhaba
# 3     18754629                       Dominos Pizza    Quick Bites
# 4      3502144                     Mannu Fast Food    Quick Bites
# ...        ...                                 ...            ...
# 2572   3500497                           Mirabilia  Casual Dining
# 2573   3500393               The Buffet Snack Shop         Bakery
# 2574  18888295                     The Swings Cafe  Casual Dining
# 2575   3500913                         Edens Grove  Casual Dining
# 2576   3500096  Vatika Restaurant - Hotel Madhuban    Fine Dining
#
#                                                     url  \
# 0     https://www.zomato.com/dehradun/doon-darbar-pa...
# 1     https://www.zomato.com/dehradun/gaylord-xpress...
# ...

# %%
new_data.drop(columns='index',axis=1,inplace=True)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2577 entries, 0 to 2576
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   res_id                2577 non-null   int64
#  1   name                  2577 non-null   object
#  2   establishment         2554 non-null   object
#  3   url                   2577 non-null   object
#  4   address               2577 non-null   object
#  5   city                  2577 non-null   object
#  6   city_id               2577 non-null   int64
#  7   locality              2577 non-null   object
#  8   latitude              2577 non-null   float64
#  9   longitude             2577 non-null   float64
#  10  country_id            2577 non-null   int64
#  11  locality_verbose      2577 non-null   object
#  12  cuisines              2564 non-null   object
#  13  timings               2573 non-null   object
#  14  average_cost_for_two  2577 non-null   int64
# ...

# %%
! git add Dehradun_zomato_dataset
# Out:
# fatal: Unable to create 'C:/Users/hp/.git/index.lock': File exists.
#
# Another git process seems to be running in this repository, e.g.
# an editor opened by 'git commit'. Please make sure all processes
# are terminated then try again. If it still fails, a git process
# may have crashed in this repository earlier:
# remove the file manually to continue.
